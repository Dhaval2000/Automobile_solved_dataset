# %% [markdown]
# ## Automobile Data

# %% [markdown]
# #### Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Task 1 : Read the DataFrame

# %%
auto_data = pd.read_csv('Automobile_data.csv')

# %%
auto_data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  highway-mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Task 2 : Most body style used comapred to no.of doors and no.of make

# %%
print(auto_data[['body-style','num-of-doors']].head(10))
# Out:
#     body-style num-of-doors
# 0  convertible          two
# 1  convertible          two
# 2    hatchback          two
# 3        sedan         four
# 4        sedan         four
# 5        sedan          two
# 6        sedan         four
# 7        wagon         four
# 8        sedan         four
# 9    hatchback          two

# %%
print(auto_data[['body-style','num-of-doors']].count())
# Out:
# body-style      205
# num-of-doors    205
# dtype: int64

# %%
#prices = auto_data.groupby('body-style').mean()['num-of-doors']
#print(prices)

auto_data.groupby(['num-of-doors','body-style']).count()
# Out:
#                           symboling  normalized-losses  make  fuel-type  \
# num-of-doors body-style
# four         hatchback           10                 10    10         10
#              sedan               81                 81    81         81
#              wagon               25                 25    25         25
# two          convertible          6                  6     6          6
#              hardtop              8                  8     8          8
#              hatchback           60                 60    60         60
#              sedan               15                 15    15         15
#
#                           aspiration  drive-wheels  engine-location  \
# num-of-doors body-style
# four         hatchback            10            10               10
#              sedan                81            81               81
#              wagon                25            25               25
# two          convertible           6             6                6
#              hardtop               8             8                8
#              hatchback            60            60               60
#              sedan                15            15               15
#
#                           wheel-base  length  width  ...    engine-size  \
# num-of-doors body-style                              ...
# four         hatchback            10      10     10  ...             10
#              sedan                81      81     81  ...             81
#              wagon                25      25     25  ...             25
# two          convertible           6       6      6  ...              6
#              hardtop               8       8      8  ...              8
#              hatchback            60      60     60  ...             60
#              sedan                15      15     15  ...             15
#
#                           fuel-system  bore  stroke  compression-ratio  \
# num-of-doors body-style
# four         hatchback             10    10      10                 10
#              sedan                 81    81      81                 81
#              wagon                 25    25      25                 25
# two          convertible            6     6       6                  6
#              hardtop                8     8       8                  8
#              hatchback             60    60      60                 60
#              sedan                 15    15      15                 15
#
#                           horsepower  peak-rpm  city-mpg  highway-mpg  price
# num-of-doors body-style
# four         hatchback            10        10        10           10     10
#              sedan                81        81        81           81     81
#              wagon                25        25        25           25     25
# two          convertible           6         6         6            6      6
#              hardtop               8         8         8            8      8
#              hatchback            60        60        60           60     60
#              sedan                15        15        15           15     15
#
# [7 rows x 24 columns]

# %% [markdown]
# #### Task 3 : What is fuel type in each car model with compared to horsepower

# %%
auto_data['fuel-type'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
car = auto_data.groupby(['make','fuel-type'])
rpm = car['make','horsepower'].count()
rpm
# Out:
#                          make  horsepower
# make          fuel-type
# alfa-romero   gas           3           3
# audi          gas           7           7
# bmw           gas           8           8
# chevrolet     gas           3           3
# dodge         gas           9           9
# honda         gas          13          13
# isuzu         gas           4           4
# jaguar        gas           3           3
# mazda         diesel        2           2
#               gas          15          15
# mercedes-benz diesel        4           4
#               gas           4           4
# mercury       gas           1           1
# mitsubishi    gas          13          13
# nissan        diesel        1           1
#               gas          17          17
# peugot        diesel        5           5
#               gas           6           6
# plymouth      gas           7           7
# porsche       gas           5           5
# renault       gas           2           2
# saab          gas           6           6
# subaru        gas          12          12
# toyota        diesel        3           3
#               gas          29          29
# volkswagen    diesel        4           4
#               gas           8           8
# volvo         diesel        1           1
#               gas          10          10

# %% [markdown]
# #### Task 4 : Highest horsepower   according to the make and peak-rpm

# %%
auto_data.sort_values(["horsepower" , "peak-rpm"], axis=0, ascending=False, inplace=True)
auto_data.head()
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 129          1                186  porsche       gas        std          two
# 49           0                145   jaguar       gas        std          two
# 126          3                186  porsche       gas        std          two
# 127          3                186  porsche       gas        std          two
# 128          3                186  porsche       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 129    hatchback          rwd           front        98.4  ...            203
# 49         sedan          rwd           front       102.0  ...            326
# 126      hardtop          rwd            rear        89.5  ...            194
# 127      hardtop          rwd            rear        89.5  ...            194
# 128  convertible          rwd            rear        89.5  ...            194
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 129         mpfi  3.94    3.11              10.0        288      5750
# 49          mpfi  3.54    2.76              11.5        262      5000
# 126         mpfi  3.74    2.90               9.5        207      5900
# 127         mpfi  3.74    2.90               9.5        207      5900
# 128         mpfi  3.74    2.90               9.5        207      5900
#
#     city-mpg  highway-mpg  price
# 129       17           28  38703
# 49        13           17  36000
# 126       17           25  32528
# 127       17           25  34028
# 128       17           25  37028
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Task 5 : Find the most expensive car company name

# %%
auto_data = auto_data [['make','price']][auto_data.price==auto_data['price'].max()]
auto_data
# Out:
#              make  price
# 74  mercedes-benz  45400

# %% [markdown]
# #### Task 6 : Sort all cars by Price column

# %%
auto_data = auto_data.sort_values(by=['price', 'horsepower'], ascending=False)
auto_data.head(5)
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 74           1                142  mercedes-benz       gas        std
# 16           0                121            bmw       gas        std
# 73           0                142  mercedes-benz       gas        std
# 129          1                186        porsche       gas        std
# 128          3                186        porsche       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 74           two      hardtop          rwd           front       112.0  ...
# 16           two        sedan          rwd           front       103.5  ...
# 73          four        sedan          rwd           front       120.9  ...
# 129          two    hatchback          rwd           front        98.4  ...
# 128          two  convertible          rwd            rear        89.5  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 74           304         mpfi  3.80    3.35               8.0        184
# 16           209         mpfi  3.62    3.39               8.0        182
# 73           308         mpfi  3.80    3.35               8.0        184
# 129          203         mpfi  3.94    3.11              10.0        288
# 128          194         mpfi  3.74    2.90               9.5        207
#
#      peak-rpm city-mpg  highway-mpg  price
# 74       4500       14           16  45400
# 16       5400       16           22  41315
# 73       4500       14           16  40960
# 129      5750       17           28  38703
# 128      5900       17           25  37028
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Task 7 : Find the average mileage of each car making company

# %%
car = auto_data.groupby('make')
rpm = car['make','peak-rpm'].mean()
rpm
# Out:
#                   peak-rpm
# make
# alfa-romero    5000.000000
# audi           5500.000000
# bmw            5068.750000
# chevrolet      5300.000000
# dodge          5388.888889
# honda          5753.846154
# isuzu          5150.000000
# jaguar         4833.333333
# mazda          5108.823529
# mercedes-benz  4487.500000
# mercury        5000.000000
# mitsubishi     5269.230769
# nissan         5177.777778
# peugot         4668.181818
# plymouth       5357.142857
# porsche        5790.000000
# renault        5550.000000
# saab           5333.333333
# subaru         4775.000000
# toyota         4859.375000
# volkswagen     5154.166667
# volvo          5290.909091

# %% [markdown]
# #### Task 8 : Find each company’s Higesht price car

# %%
cars = auto_data.groupby('make')
prices = cars['make','price'].max()
prices
# Out:
#                         make  price
# make
# alfa-romero      alfa-romero  16500
# audi                    audi  24875
# bmw                      bmw  41315
# chevrolet          chevrolet   6575
# dodge                  dodge  12964
# honda                  honda  12945
# isuzu                  isuzu  11048
# jaguar                jaguar  36000
# mazda                  mazda  18344
# mercedes-benz  mercedes-benz  45400
# mercury              mercury  16503
# mitsubishi        mitsubishi  14869
# nissan                nissan  19699
# peugot                peugot  18150
# plymouth            plymouth  12764
# porsche              porsche  38703
# renault              renault   9895
# saab                    saab  18620
# subaru                subaru  11694
# toyota                toyota  17669
# volkswagen        volkswagen  13845
# volvo                  volvo  22625

# %% [markdown]
# #### Task 9 : Count total cars per company

# %%
auto_data['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# bmw               8
# mercedes-benz     8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
g = sns.factorplot("make", data=auto_data, aspect=1.5, kind="count", color="b")
g.set_xticklabels(rotation=90)
# Out:
# C:\Users\Dhaval\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# #### Task 10 : Print All Toyota Cars details

# %%
car = auto_data.groupby('make')
audi = car.get_group('alfa-romero')
audi
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
#
#    peak-rpm city-mpg  highway-mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
#
# [3 rows x 26 columns]
